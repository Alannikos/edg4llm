# %%
import sys
sys.path.append("/home/alannikos/Project_Repository/edg4llm_workplace/edg4llm_local")

import edg4llm

# %%
print(edg4llm.__version__)
# Out:
# 0.1.0

# %%
from edg4llm.core.interface import EDG4LLM

api_key = "xxx"
base_url = "https://internlm-chat.intern-ai.org.cn/puyu/api/v1/chat/completions"

edg = EDG4LLM(model_provider='internlm', model_name="internlm2.5-latest", base_url=base_url, api_key=api_key)
# 设置测试数据
system_prompt = """你是一个精通中国古代诗词的古文学大师"""

user_prompt = '''
    目标: 1. 请生成过年为场景的连续多轮对话记录
            2. 提出的问题要多样化。
            3. 要符合人类的说话习惯。
            4. 严格遵循规则: 请以如下格式返回生成的数据, 只返回JSON格式，json模板:  
                [
                    {{
                        "input":"AAA","output":"BBBB" 
                    }}
                ]
                其中input字段表示一个人的话语, output字段表示专家的话语'''
num_samples = 3  # 只生成一个对话样本

# 调用 generate 方法生成对话
data = edg.generate(
    task_type="dialogue",
    system_prompt=system_prompt,
    user_prompt=user_prompt,
    num_samples=num_samples
)
# Out:
# [2025-01-10 11:06:14,316]-[interface:INFO]:DataPipeline initialized successfully with the provided configuration.
# [2025-01-10 11:06:14,317]-[DataPipeline:INFO]:Generated data for task_type: 'dialogue'
# [2025-01-10 11:06:25,520]-[DialogueGenerator:INFO]:Data generation progress: 33.33% (1/3 samples completed)
# [2025-01-10 11:06:55,552]-[internlm:ERROR]:Timeout occurred while sending request to https://internlm-chat.intern-ai.org.cn/puyu/api/v1/chat/completions: HTTPSConnectionPool(host='internlm-chat.intern-ai.org.cn', port=443): Read timed out. (read timeout=30)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connectionpool.py:773, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     772 try:
# --> 773     self._prepare_proxy(conn)
#     774 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1036 conn.set_tunnel(
#    1037     scheme=tunnel_scheme,
#    1038     host=self._tunnel_host,
#    1039     port=self.port,
#    1040     headers=self.proxy_headers,
#    1041 )
# -> 1042 conn.connect()
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742     sock=sock,
#     743     cert_reqs=self.cert_reqs,
#     744     ssl_version=self.ssl_version,
#     745     ssl_minimum_version=self.ssl_minimum_version,
#     746     ssl_maximum_version=self.ssl_maximum_version,
#     747     ca_certs=self.ca_certs,
#     748     ca_cert_dir=self.ca_cert_dir,
#     749     ca_cert_data=self.ca_cert_data,
#     750     cert_file=self.cert_file,
#     751     key_file=self.key_file,
#     752     key_password=self.key_password,
#     753     server_hostname=server_hostname_rm_dot,
#     754     ssl_context=self.ssl_context,
#     755     tls_in_tls=tls_in_tls,
#     756     assert_hostname=self.assert_hostname,
#     757     assert_fingerprint=self.assert_fingerprint,
#     758 )
#     759 self.sock = sock_and_verified.socket
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connection.py:920, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     918         server_hostname = normalized
# --> 920 ssl_sock = ssl_wrap_socket(
#     921     sock=sock,
#     922     keyfile=key_file,
#     923     certfile=cert_file,
#     924     key_password=key_password,
#     925     ca_certs=ca_certs,
#     926     ca_cert_dir=ca_cert_dir,
#     927     ca_cert_data=ca_cert_data,
#     928     server_hostname=server_hostname,
#     929     ssl_context=context,
#     930     tls_in_tls=tls_in_tls,
#     931 )
#     933 try:
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/util/ssl_.py:460, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     458 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 460 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461 return ssl_sock
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/util/ssl_.py:504, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     502     return SSLTransport(sock, ssl_context, server_hostname)
# --> 504 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/ssl.py:512, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     506 def wrap_socket(self, sock, server_side=False,
#     507                 do_handshake_on_connect=True,
#     508                 suppress_ragged_eofs=True,
#     509                 server_hostname=None, session=None):
#     510     # SSLSocket class handles server_hostname encoding before it calls
#     511     # ctx._wrap_socket()
# --> 512     return self.sslsocket_class._create(
#     513         sock=sock,
#     514         server_side=server_side,
#     515         do_handshake_on_connect=do_handshake_on_connect,
#     516         suppress_ragged_eofs=suppress_ragged_eofs,
#     517         server_hostname=server_hostname,
#     518         context=self,
#     519         session=session
#     520     )
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/ssl.py:1070, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1069             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1070         self.do_handshake()
#    1071 except (OSError, ValueError):
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/ssl.py:1341, in SSLSocket.do_handshake(self, block)
#    1340         self.settimeout(None)
# -> 1341     self._sslobj.do_handshake()
#    1342 finally:
#
# TimeoutError: _ssl.c:980: The handshake operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connectionpool.py:775, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     774 except (BaseSSLError, OSError, SocketTimeout) as e:
# --> 775     self._raise_timeout(
#     776         err=e, url=self.proxy.url, timeout_value=conn.timeout
#     777     )
#     778     raise
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='internlm-chat.intern-ai.org.cn', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/models/internlm.py:51, in EDGInternLM._send_request(self, request)
#      50 try:
# ---> 51     response = requests.post(
#      52         url=url,
#      53         headers=headers,
#      54         json=json,
#      55         timeout=30,
#      56     )
#      58     response.raise_for_status()
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/miniconda3/envs/edg4llm/lib/python3.10/site-packages/requests/adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='internlm-chat.intern-ai.org.cn', port=443): Read timed out. (read timeout=30)
#
# The above exception was the direct cause of the following exception:
#
# HttpClientError                           Traceback (most recent call last)
# Cell In[10], line 24
#      21 num_samples = 3  # 只生成一个对话样本
#      23 # 调用 generate 方法生成对话
# ---> 24 data = edg.generate(
#      25     task_type="dialogue",
#      26     system_prompt=system_prompt,
#      27     user_prompt=user_prompt,
#      28     num_samples=num_samples
#      29 )
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/core/interface.py:196, in EDG4LLM.generate(self, task_type, system_prompt, user_prompt, do_sample, temperature, top_p, max_tokens, num_samples, output_format)
#     107 def generate(self
#     108             , task_type: str = 'dialogue'
#     109             , system_prompt: str = None
#    (...)
#     116             , output_format: str = "alpaca"
#     117             ):
#     118     """
#     119     Generate text data based on the specified configuration.
#     120
#    (...)
#     193     based on the provided configuration.
#     194     """
# --> 196     data = self._generate(task_type, system_prompt, user_prompt, do_sample, temperature, top_p, max_tokens, num_samples, output_format)
#     197     logger.info("Data generation completed successfully for task_type: %s", task_type)
#     199     return data
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/core/interface.py:302, in EDG4LLM._generate(self, task_type, system_prompt, user_prompt, do_sample, temperature, top_p, max_tokens, num_samples, output_format)
#     289 self._tConfig = {
#     290     "task_type": task_type,         # The type of task for data generation
#     291     "system_prompt": system_prompt, # The system-level prompt
#    (...)
#     298     "output_format": output_format  # Desired output format
#     299 }
#     301 # Call the pipeline's generate_data method using the configuration dictionary
# --> 302 data = self.pipeline.generate_data(self._tConfig)
#     304 return data
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/core/pipeline.py:84, in DataPipeline.generate_data(self, tConfig)
#      82 elif tConfig["task_type"] == "dialogue":
#      83     logger.info("Generated data for task_type: 'dialogue'")
# ---> 84     data = self.data_generator.generate_dialogue(tConfig)
#      85 else:
#      86     logger.error("Unsupported task type: %s", tConfig["task_type"])
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/core/dataGenerators.py:155, in DataGenerator.generate_dialogue(self, tConfig)
#     108 def generate_dialogue(self, tConfig) -> list[Dict]:
#     109     """
#     110     Generate a dialogue based on the given configuration.
#     111
#    (...)
#     152       and various sampling strategies.
#     153     """
# --> 155     data = self.dialogue_generator.generate(tConfig)
#     156     return data
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/text_generators/dialogue_generator.py:104, in DialogueGenerator.generate(self, tConfig)
#     102 for _idx in range(1, num_samples + 1):
#     103     while True:  # Keep trying until valid dialogue data is generated
# --> 104         generated_dialogue = self.model.execute_request(
#     105             system_prompt=system_prompt,
#     106             user_prompt=user_prompt,
#     107             do_sample=do_sample,
#     108             temperature=temperature,
#     109             top_p=top_p,
#     110             max_tokens=max_tokens,
#     111         )
#     113         # Convert the generated dialogue to the desired format (e.g., Alpaca format)
#     114         converted_generated_dialogue = self._convert_original_to_alpaca(system_prompt, generated_dialogue)
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/models/internlm.py:38, in EDGInternLM.execute_request(self, system_prompt, user_prompt, model, do_sample, temperature, top_p, max_tokens)
#      20 def execute_request(
#      21         self
#      22         , system_prompt: str = None
#    (...)
#      28         , max_tokens: int = 4095
#      29         ) -> str:
#      30     """
#      31     调用模型生成数据
#      32
#    (...)
#      35     :return: 生成的文本
#      36     """
# ---> 38     response = self._execute_request(system_prompt, user_prompt, model, do_sample, temperature, top_p, max_tokens)
#      39     return response
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/models/internlm.py:151, in EDGInternLM._execute_request(self, system_prompt, user_prompt, model, do_sample, temperature, top_p, max_tokens)
#     125     raise InvalidPromptError("prompt不能同时为空")
#     127 request_data = {
#     128     "url": f"{self.base_url}",
#     129     "headers": {
#    (...)
#     148     },
#     149 }
# --> 151 response = self.send_request(request_data)
#     152 return response["choices"][0]["message"]["content"].strip()
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/models/internlm.py:42, in EDGInternLM.send_request(self, request)
#      41 def send_request(self, request: Dict[str, Any]) -> Dict[str, Any]:
# ---> 42     response = self._send_request(request=request)
#      43     return response
#
# File ~/Project_Repository/edg4llm_workplace/edg4llm_local/edg4llm/models/internlm.py:85, in EDGInternLM._send_request(self, request)
#      82 except requests.exceptions.Timeout as e:
#      83     # Handle timeout errors
#      84     logger.error("Timeout occurred while sending request to %s: %s", url, e)
# ---> 85     raise HttpClientError(
#      86         f"Request timed out while connecting to {url}: {e}"
#      87     ) from e
#      89 except requests.exceptions.RequestException as e:
#      90     # Handle generic request exceptions
#      91     logger.error(
#      92         "Request exception occurred while sending request to %s: %s", url, e
#      93     )
#
# HttpClientError: Request timed out while connecting to https://internlm-chat.intern-ai.org.cn/puyu/api/v1/chat/completions: HTTPSConnectionPool(host='internlm-chat.intern-ai.org.cn', port=443): Read timed out. (read timeout=30)

# %%
print(data)
